# %%
# %run ./som.py
# Out:
#       Lat     Long   Tm    Tx   Tn      P
# 0  48.935 -123.742  7.7  15.0 -1.0  104.3
# 2  48.432 -123.439  7.5  13.3 -0.7   42.2
# 3  48.575 -123.530  6.0  13.2 -0.5   90.6
# 6  48.824 -123.719  7.2  15.9 -5.0   81.3
# 7  48.764 -123.287  8.0  15.0 -1.0   81.0
# Topographic error = 0.06618407445708377; Quantization error = 0.49376112680752715
# Performing K-means SSE elbow sweep...
# Centroid 0[  53.39011134 -116.59128371   -2.11983525   14.56753255  -20.99812076
#    15.26373725]
# Centroid 1[ 47.02746734 -67.90388904  -3.330462    10.84596142 -21.36423429
#   99.06438205]
# Centroid 2[ 49.98377161 -76.06071637  -8.69889239   7.64426604 -29.67386339
#   40.79166367]
# Centroid 3[  50.0147098  -123.03252003    5.44109638   14.50122286   -4.80185088
#   134.89971791]
# Centroid 4[  52.13970706 -108.66746489   -4.97193266   13.26051333  -28.15646791
#    13.46922219]
# Centroid 5[  50.42184801 -125.72043245    6.63530388   14.02804156   -1.20873823
#   218.10248277]
# ...
